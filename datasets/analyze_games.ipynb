# %%
import torch
import chess.pgn
import chess.engine

# %%
rating_ranges = [
    (800, 1000), (1000, 1200), (1200, 1400), (1400, 1600), (1600, 1800),
    (1800, 2000), (2000, 2200), (2200, 2400), (2400, 2600), (2600, 3000)
]

# %% [markdown]
# ### Load Games

# %%
chess_games = {rating: [] for rating in rating_ranges}
min_elo = 9999
max_elo = 0

for rating_range in rating_ranges:
    lower_bound = rating_range[0]
    upper_bound = rating_range[1]
    
    file = f"outputs/{str(lower_bound)}-{str(upper_bound)}.pgn"


    with open(file) as f:
        while len(chess_games[rating_range]) < 200:
            game = chess.pgn.read_game(f)
            if game is None:
                break
            if any(time_control in game.headers["Event"] for time_control in [
                "Correspondence", "Daily", "Classical, Bullet, UltraBullet"
            ]):
                continue
            if game.headers["WhiteElo"] == "?" or game.headers["BlackElo"] == "?":
                continue
            if (
                not lower_bound <= int(game.headers["WhiteElo"]) <= upper_bound
                or not lower_bound <= int(game.headers["BlackElo"]) <= upper_bound
            ):
                continue
            if not game.mainline_moves():
                continue
            
            chess_games[rating_range].append(game)
            
            min_elo = min(min_elo, int(game.headers["WhiteElo"]), int(game.headers["BlackElo"]))
            max_elo = max(max_elo, int(game.headers["WhiteElo"]), int(game.headers["BlackElo"]))
            
    print(f"{rating_range} games: {len(chess_games[rating_range])} done")
    
print(f"Min elo: {min_elo}, Max elo: {max_elo}")
# Out:
# (800, 1000) games: 200 done
# (1000, 1200) games: 200 done
# (1200, 1400) games: 200 done
# (1400, 1600) games: 200 done
# (1600, 1800) games: 200 done
# (1800, 2000) games: 200 done
# (2000, 2200) games: 200 done
# (2200, 2400) games: 200 done
# (2400, 2600) games: 200 done
# (2600, 3000) games: 200 done
# Min elo: 800, Max elo: 2853

# %% [markdown]
# ### Analyze the games

# %%
def fen_to_bitboard(fen_str):
    mapings = {
        "P": 0, "N": 1, "B": 2, "R": 3, "Q": 4, "K": 5,
        "p": 6, "n": 7, "b": 8, "r": 9, "q": 10, "k": 11
    }   
    
    bitboard = torch.zeros(12, 64)
    fen, move, _castle, _en_passant, _halfmove, _fullmove = fen_str.split(" ")
    row, col = 0, 0
    for char in fen:
        if char == "/":
            row += 1
            col = 0
        elif char.isdigit():
            col += int(char)
        else:
            bitboard[mapings[char], row * 8 + col] = 1
            col += 1
    # Flatten the bitboard and add whose move it is
    return torch.cat((torch.tensor([1 if move == "w" else -1]), bitboard.flatten()))

# %%
def pad_tensor(tensor, length):
    return torch.cat((tensor, torch.ones(length - len(tensor)) * -mate_score))

def analyze_game(game, engine, mate_score, nof_moves=10):
    board = game.board()
    analysis = []
    
    for i, move in enumerate(game.mainline_moves()):
        # Enfine evaluation before the move
        top_moves = engine.analyse(board, chess.engine.Limit(time=0.1), multipv=nof_moves)
        # A tensor with the score of the top nof_moves moves (normalized to be between -1 and 1)
        top_moves_tensor = torch.Tensor([eval["score"].relative.score(mate_score=mate_score) for eval in top_moves]) 
        # Pad the tensor if there are less than nof_moves legal moves
        top_moves_tensor = pad_tensor(top_moves_tensor, nof_moves) / mate_score
        # Win, draw, loss chance tensor before the move
        before_wdl = top_moves[0]["score"].relative.wdl()
        before_wdl_tensor = torch.Tensor([
            before_wdl.winning_chance(), 
            before_wdl.drawing_chance(), 
            before_wdl.losing_chance()
        ])
        board.push(move)
        
        # Engine evaluation after the move
        after_move = engine.analyse(board, chess.engine.Limit(time=0.1))
        # Now it's the opponent's turn so negate the score
        after_move_tensor = torch.Tensor([after_move["score"].relative.score(mate_score=mate_score) * -1]) / mate_score
        # Reverse the list so that it's from the perspective of the player who just moved
        after_wdl = after_move["score"].relative.wdl()
        after_wdl_tensor = torch.Tensor([
            after_wdl.losing_chance(), 
            after_wdl.drawing_chance(), 
            after_wdl.winning_chance()
        ])

        analysis.append(torch.cat((
            top_moves_tensor, before_wdl_tensor, 
            after_move_tensor, after_wdl_tensor
        )))
        # print(f"before move: {move}, top_moves {top_moves_tensor}, wdl {before_wdl_tensor}")
        # print(f"after:               top_moves {after_move_tensor}, wdl {after_wdl_tensor}")
    
    # Pad the game if it ends on white's turn to batch white's and black's analysis together
    if len(analysis) % 2:
        analysis.append(torch.ones_like(analysis[0]) * (-mate_score))
    
    white_analysis = torch.stack([position for position in analysis[::2]])
    black_analysis = torch.stack([position for position in analysis[1::2]])
    
    white_elo = int(game.headers["WhiteElo"])
    black_elo = int(game.headers["BlackElo"])
    
    return torch.stack((white_analysis, black_analysis)), torch.Tensor([white_elo, black_elo])

def analyze_games(rating_range, games, n=None):
    analysis = []
    elo = []
    
    engine = chess.engine.SimpleEngine.popen_uci("/usr/bin/stockfish")
    mate_score = 1_000

    for i, game in enumerate(games[:n]):
        analysis_tensor, elo_tensor = analyze_game(game, engine, mate_score)
        analysis.append(analysis_tensor)
        elo.append(elo_tensor)
        
        if i % 20 == -1:
            print(f"{rating_range} game {i + 1} done")
            
    engine.close()
    print(f"{rating_range} done")
    
    return analysis, elo

# %%
def convert_position(game):
    board = game.board()
    positions = []
    
    for move in game.mainline_moves():
        board_position_tensor = fen_to_bitboard(board.fen())
        positions.append(board_position_tensor)
        board.push(move)
        
    # Pad the game if it ends on white's turn to batch white's and black's analysis together later
    if len(positions) % 2:
        positions.append(torch.zeros_like(positions[0]))
    
    white_positions = torch.stack([position for position in positions[::2]])
    black_positions = torch.stack([position for position in positions[1::2]])
    
    white_elo = int(game.headers["WhiteElo"])
    black_elo = int(game.headers["BlackElo"])
    
    return torch.stack((white_positions, black_positions)), torch.Tensor([white_elo, black_elo])
    

def convert_positions_to_tensors(dataset):
    positions = []
    elo = []
    
    for rating_range, games in dataset.items():
        for game in games:
            position_tensor, elo_tensor = convert_position(game)
            positions.append(position_tensor)
            elo.append(elo_tensor)
            
        print(f"{rating_range} done")
        
    return positions, elo

# %%
positions, elo = convert_positions_to_tensors(chess_games)
# Out:
# (800, 1000) done
# (1000, 1200) done
# (1200, 1400) done
# (1400, 1600) done
# (1600, 1800) done
# (1800, 2000) done
# (2000, 2200) done
# (2200, 2400) done
# (2400, 2600) done
# (2600, 3000) done

# %%
torch.save((positions, elo), "all_board_positions.pt")

# %%
import multiprocessing as mp

# pool = mp.Pool(processes=mp.cpu_count())
pool = mp.Pool(processes=10)

n = None
args = [(label, games, n) for label, games in chess_games.items()]

output = pool.starmap(analyze_games, args)

pool.close()
pool.join()
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_450210/3273686206.py", line 63, in analyze_games
#     analysis_tensor, elo_tensor = analyze_game(game, engine, mate_score)
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_450210/3273686206.py", line 14, in analyze_game
#     top_moves_tensor = pad_tensor(top_moves_tensor, nof_moves) / mate_score
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_450210/3273686206.py", line 2, in pad_tensor
#     return torch.cat((tensor, torch.ones(length - len(tensor)) * -mate_score))
#                                                                   ^^^^^^^^^^
# NameError: name 'mate_score' is not defined
# """
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 n = None
#       7 args = [(label, games, n) for label, games in chess_games.items()]
# ----> 9 output = pool.starmap(analyze_games, args)
#      11 pool.close()
#      12 pool.join()
#
# File /usr/lib/python3.11/multiprocessing/pool.py:375, in Pool.starmap(self, func, iterable, chunksize)
#     369 def starmap(self, func, iterable, chunksize=None):
#     370     '''
#     371     Like `map()` method but the elements of the `iterable` are expected to
#     372     be iterables as well and will be unpacked as arguments. Hence
#     373     `func` and (a, b) becomes func(a, b).
#     374     '''
# --> 375     return self._map_async(func, iterable, starmapstar, chunksize).get()
#
# File /usr/lib/python3.11/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# NameError: name 'mate_score' is not defined

# %%
analysis = [game for games, _ in output for game in games]
elo = [elo for _, elos in output for elo in elos]
# Out:
# 20 20
# torch.Size([2, 59, 17]) torch.Size([2])

# %%
# Out:
# 2

# %%
torch.save((analysis, elo), "all_analysis.pt")

# %%
game = chess.pgn.read_game(open("../my_game1.pgn"))
a = analyze_game(game)
# Out:
# before move: d2d4, top_moves tensor([ 0.0039,  0.0037,  0.0028,  0.0023,  0.0022,  0.0017,  0.0016,  0.0009,
#          0.0002, -0.0008]), wdl tensor([0.0410, 0.9580, 0.0010])
# after:               top_moves tensor([0.0029]), wdl tensor([0.0240, 0.9750, 0.0010])
# before move: f7f5, top_moves tensor([-0.0035, -0.0036, -0.0044, -0.0054, -0.0054, -0.0044, -0.0054, -0.0059,
#         -0.0062, -0.0065]), wdl tensor([0.0010, 0.9660, 0.0330])
# after:               top_moves tensor([-0.0065]), wdl tensor([0.0000, 0.8520, 0.1480])
# before move: c2c4, top_moves tensor([0.0074, 0.0059, 0.0053, 0.0051, 0.0051, 0.0048, 0.0044, 0.0037, 0.0032,
#         0.0030]), wdl tensor([0.2200, 0.7800, 0.0000])
# after:               top_moves tensor([0.0055]), wdl tensor([0.0920, 0.9080, 0.0000])
# before move: g8f6, top_moves tensor([-0.0054, -0.0055, -0.0067, -0.0075, -0.0077, -0.0078, -0.0082, -0.0084,
#         -0.0084, -0.0093]), wdl tensor([0.0000, 0.9120, 0.0880])
# after:               top_moves tensor([-0.0061]), wdl tensor([0.0000, 0.8770, 0.1230])
# before move: b1c3, top_moves tensor([0.0055, 0.0059, 0.0059, 0.0059, 0.0058, 0.0045, 0.0043, 0.0042, 0.0039,
#         0.0037]), wdl tensor([0.0920, 0.9080, 0.0000])
# after:               top_moves tensor([0.0060]), wdl tensor([0.1170, 0.8830, 0.0000])
# before move: g7g6, top_moves tensor([-0.0058, -0.0062, -0.0065, -0.0066, -0.0070, -0.0075, -0.0078, -0.0079,
#         -0.0084, -0.0085]), wdl tensor([0.0000, 0.8930, 0.1070])
# after:               top_moves tensor([-0.0063]), wdl tensor([0.0000, 0.8650, 0.1350])
# before move: e2e3, top_moves tensor([0.0057, 0.0056, 0.0065, 0.0056, 0.0050, 0.0050, 0.0048, 0.0046, 0.0039,
#         0.0037]), wdl tensor([0.1020, 0.8980, 0.0000])
# after:               top_moves tensor([0.0052]), wdl tensor([0.0790, 0.9210, 0.0000])
# before move: f8g7, top_moves tensor([-0.0049, -0.0059, -0.0065, -0.0069, -0.0069, -0.0071, -0.0073, -0.0075,
#         -0.0061, -0.0080]), wdl tensor([0.0000, 0.9320, 0.0680])
# after:               top_moves tensor([-0.0065]), wdl tensor([0.0000, 0.8520, 0.1480])
# before move: g1f3, top_moves tensor([0.0063, 0.0062, 0.0056, 0.0046, 0.0039, 0.0031, 0.0030, 0.0030, 0.0028,
#         0.0020]), wdl tensor([0.1350, 0.8650, 0.0000])
# after:               top_moves tensor([0.0057]), wdl tensor([0.1020, 0.8980, 0.0000])
# before move: e8g8, top_moves tensor([-0.0054, -0.0057, -0.0059, -0.0064, -0.0064, -0.0064, -0.0065, -0.0075,
#         -0.0082, -0.0084]), wdl tensor([0.0000, 0.9120, 0.0880])
# after:               top_moves tensor([-0.0055]), wdl tensor([0.0000, 0.9080, 0.0920])
# before move: f1d3, top_moves tensor([0.0054, 0.0042, 0.0039, 0.0032, 0.0029, 0.0027, 0.0027, 0.0020, 0.0017,
#         0.0021]), wdl tensor([0.0880, 0.9120, 0.0000])
# after:               top_moves tensor([0.0044]), wdl tensor([0.0530, 0.9470, 0.0000])
# before move: d7d6, top_moves tensor([-0.0040, -0.0046, -0.0052, -0.0052, -0.0055, -0.0075, -0.0070, -0.0071,
#         -0.0072, -0.0074]), wdl tensor([0.0010, 0.9560, 0.0430])
# after:               top_moves tensor([-0.0035]), wdl tensor([0.0010, 0.9660, 0.0330])
# before move: e1g1, top_moves tensor([ 0.0038,  0.0000, -0.0008, -0.0016, -0.0018, -0.0018, -0.0027, -0.0029,
#         -0.0031, -0.0034]), wdl tensor([0.0390, 0.9600, 0.0010])
# after:               top_moves tensor([0.0040]), wdl tensor([0.0430, 0.9560, 0.0010])
# before move: a7a6, top_moves tensor([-0.0031, -0.0031, -0.0032, -0.0035, -0.0050, -0.0047, -0.0047, -0.0056,
#         -0.0066, -0.0083]), wdl tensor([0.0010, 0.9720, 0.0270])
# after:               top_moves tensor([-0.0075]), wdl tensor([0.0000, 0.7710, 0.2290])
# before move: h2h3, top_moves tensor([0.0070, 0.0050, 0.0050, 0.0047, 0.0047, 0.0046, 0.0036, 0.0030, 0.0008,
#         0.0015]), wdl tensor([0.1850, 0.8150, 0.0000])
# after:               top_moves tensor([0.0012]), wdl tensor([0.0100, 0.9870, 0.0030])
# before move: d8e8, top_moves tensor([-0.0030, -0.0056, -0.0054, -0.0073, -0.0086, -0.0087, -0.0088, -0.0091,
#         -0.0096, -0.0097]), wdl tensor([0.0010, 0.9730, 0.0260])
# after:               top_moves tensor([-0.0083]), wdl tensor([0.0000, 0.6860, 0.3140])
# before move: b2b4, top_moves tensor([0.0096, 0.0083, 0.0076, 0.0064, 0.0062, 0.0057, 0.0055, 0.0054, 0.0040,
#         0.0033]), wdl tensor([0.4790, 0.5210, 0.0000])
# after:               top_moves tensor([0.0039]), wdl tensor([0.0410, 0.9580, 0.0010])
# before move: b8c6, top_moves tensor([-0.0035, -0.0063, -0.0075, -0.0075, -0.0082, -0.0085, -0.0093, -0.0095,
#         -0.0099, -0.0103]), wdl tensor([0.0010, 0.9660, 0.0330])
# after:               top_moves tensor([-0.0077]), wdl tensor([0.0000, 0.7510, 0.2490])
# before move: b4b5, top_moves tensor([ 0.0067,  0.0027,  0.0021,  0.0008,  0.0001, -0.0003, -0.0004, -0.0016,
#         -0.0017, -0.0041]), wdl tensor([0.1620, 0.8380, 0.0000])
# after:               top_moves tensor([0.0092]), wdl tensor([0.4260, 0.5740, 0.0000])
# before move: a6b5, top_moves tensor([-0.0086, -0.0093, -0.0094, -0.0111, -0.0135, -0.0141, -0.0166, -0.0290,
#         -0.0300, -0.0368]), wdl tensor([0.0000, 0.6510, 0.3490])
# after:               top_moves tensor([-0.0081]), wdl tensor([0.0000, 0.7090, 0.2910])
# before move: c3b5, top_moves tensor([ 0.0077,  0.0030, -0.0033, -0.0048, -0.0065, -0.0067, -0.0067, -0.0073,
#         -0.0092, -0.0100]), wdl tensor([0.2490, 0.7510, 0.0000])
# after:               top_moves tensor([0.0042]), wdl tensor([0.0480, 0.9510, 0.0010])
# before move: e8d7, top_moves tensor([-0.0042, -0.0042, -0.0166, -0.0201, -0.0275, -0.0277, -0.0298, -0.0324,
#         -0.0367, -0.0369]), wdl tensor([0.0010, 0.9510, 0.0480])
# after:               top_moves tensor([-0.0041]), wdl tensor([0.0010, 0.9530, 0.0460])
# before move: a2a4, top_moves tensor([ 0.0037,  0.0015,  0.0004,  0.0003, -0.0002,  0.0006,  0.0006,  0.0004,
#         -0.0012, -0.0027]), wdl tensor([0.0370, 0.9620, 0.0010])
# after:               top_moves tensor([-0.0003]), wdl tensor([0.0040, 0.9900, 0.0060])
# before move: e7e5, top_moves tensor([ 0.0000, -0.0028, -0.0033, -0.0047, -0.0051, -0.0054, -0.0059, -0.0043,
#         -0.0049, -0.0062]), wdl tensor([0.0050, 0.9900, 0.0050])
# after:               top_moves tensor([0.0009]), wdl tensor([0.0080, 0.9890, 0.0030])
# before move: d4d5, top_moves tensor([-0.0012, -0.0034, -0.0034, -0.0036, -0.0047, -0.0052, -0.0053, -0.0080,
#         -0.0084, -0.0112]), wdl tensor([0.0030, 0.9870, 0.0100])
# after:               top_moves tensor([-0.0102]), wdl tensor([0.0000, 0.4410, 0.5590])
# before move: c6e7, top_moves tensor([ 0.0114,  0.0054,  0.0040,  0.0031,  0.0024, -0.0012, -0.0031, -0.0088,
#         -0.0102, -0.0088]), wdl tensor([0.7080, 0.2920, 0.0000])
# after:               top_moves tensor([-0.0044]), wdl tensor([0.0000, 0.9470, 0.0530])
# before move: f3g5, top_moves tensor([ 0.0042,  0.0022, -0.0006, -0.0025, -0.0064, -0.0100, -0.0108, -0.0118,
#         -0.0125, -0.0131]), wdl tensor([0.0480, 0.9510, 0.0010])
# after:               top_moves tensor([-0.0037]), wdl tensor([0.0010, 0.9620, 0.0370])
# before move: d7d8, top_moves tensor([ 0.0044,  0.0025, -0.0105, -0.0120, -0.0154, -0.0202, -0.0214, -0.0252,
#         -0.0255, -0.0265]), wdl tensor([0.0530, 0.9470, 0.0000])
# after:               top_moves tensor([-0.0005]), wdl tensor([0.0040, 0.9890, 0.0070])
# before move: e3e4, top_moves tensor([-0.0005,  0.0009, -0.0001, -0.0001, -0.0026, -0.0027, -0.0036, -0.0037,
#         -0.0040, -0.0049]), wdl tensor([0.0040, 0.9890, 0.0070])
# after:               top_moves tensor([-0.0044]), wdl tensor([0.0000, 0.9470, 0.0530])
# before move: f5f4, top_moves tensor([ 0.0048, -0.0042, -0.0046, -0.0038, -0.0049, -0.0057, -0.0063, -0.0075,
#         -0.0089, -0.0107]), wdl tensor([0.0650, 0.9350, 0.0000])
# after:               top_moves tensor([-0.0180]), wdl tensor([0.0000, 0.0120, 0.9880])
# before move: c1a3, top_moves tensor([0.0183, 0.0059, 0.0042, 0.0009, 0.0027, 0.0026, 0.0015, 0.0012, 0.0011,
#         0.0008]), wdl tensor([0.9900, 0.0100, 0.0000])
# after:               top_moves tensor([0.0078]), wdl tensor([0.2590, 0.7410, 0.0000])
# before move: h7h6, top_moves tensor([-0.0061, -0.0083, -0.0085, -0.0159, -0.0189, -0.0182, -0.0190, -0.0200,
#         -0.0213, -0.0217]), wdl tensor([0.0000, 0.8770, 0.1230])
# after:               top_moves tensor([-0.0096]), wdl tensor([0.0000, 0.5210, 0.4790])
# before move: g5e6, top_moves tensor([ 0.0093,  0.0092, -0.0003, -0.0077, -0.0137, -0.0186, -0.0227, -0.0222,
#         -0.0233, -0.0247]), wdl tensor([0.4390, 0.5610, 0.0000])
# after:               top_moves tensor([-0.0064]), wdl tensor([0.0000, 0.8590, 0.1410])
# before move: c8e6, top_moves tensor([ 0.0041, -0.0479, -0.0525, -0.0573, -0.0581, -0.0585, -0.0594, -0.0626,
#         -0.0577, -0.0596]), wdl tensor([0.0460, 0.9530, 0.0010])
# after:               top_moves tensor([0.0064]), wdl tensor([0.1410, 0.8590, 0.0000])
# before move: d5e6, top_moves tensor([-0.0060, -0.0078, -0.0263, -0.0265, -0.0273, -0.0274, -0.0276, -0.0278,
#         -0.0285, -0.0258]), wdl tensor([0.0000, 0.8830, 0.1170])
# after:               top_moves tensor([-0.0069]), wdl tensor([0.0000, 0.8230, 0.1770])
# before move: g6g5, top_moves tensor([ 0.0050,  0.0004, -0.0080, -0.0110, -0.0105, -0.0113, -0.0114, -0.0116,
#         -0.0133, -0.0140]), wdl tensor([0.0720, 0.9280, 0.0000])
# after:               top_moves tensor([-0.0175]), wdl tensor([0.0000, 0.0150, 0.9850])
# before move: d1b3, top_moves tensor([ 0.0183,  0.0057,  0.0041,  0.0030,  0.0019,  0.0013,  0.0000, -0.0009,
#         -0.0023,  0.0023]), wdl tensor([0.9900, 0.0100, 0.0000])
# after:               top_moves tensor([0.0021]), wdl tensor([0.0160, 0.9820, 0.0020])
# before move: h6h5, top_moves tensor([-0.0043, -0.0112, -0.0134, -0.0153, -0.0165, -0.0167, -0.0172, -0.0195,
#         -0.0233, -0.0237]), wdl tensor([0.0010, 0.9480, 0.0510])
# after:               top_moves tensor([-0.0213]), wdl tensor([0.0000, 0.0020, 0.9980])
# before move: g2g3, top_moves tensor([ 0.0205,  0.0085,  0.0069,  0.0041,  0.0016,  0.0010, -0.0001,  0.0026,
#          0.0005, -0.0012]), wdl tensor([0.9970, 0.0030, 0.0000])
# after:               top_moves tensor([-0.0055]), wdl tensor([0.0000, 0.9080, 0.0920])
# before move: c7c5, top_moves tensor([ 0.0018, -0.0062, -0.0093, -0.0129, -0.0132, -0.0135, -0.0143, -0.0147,
#         -0.0164, -0.0169]), wdl tensor([0.0140, 0.9840, 0.0020])
# after:               top_moves tensor([-0.0140]), wdl tensor([0.0000, 0.0930, 0.9070])
# before move: g3f4, top_moves tensor([ 0.0110,  0.0099,  0.0084,  0.0079,  0.0035,  0.0017, -0.0012, -0.0032,
#         -0.0038, -0.0045]), wdl tensor([0.6610, 0.3390, 0.0000])
# after:               top_moves tensor([0.0028]), wdl tensor([0.0230, 0.9760, 0.0010])
# before move: g5f4, top_moves tensor([-0.0025, -0.0117, -0.0208, -0.0185, -0.0208, -0.0223, -0.0223, -0.0236,
#         -0.0239, -0.0246]), wdl tensor([0.0010, 0.9790, 0.0200])
# after:               top_moves tensor([-0.0060]), wdl tensor([0.0000, 0.8830, 0.1170])
# before move: g1h2, top_moves tensor([ 0.0053,  0.0051,  0.0039,  0.0014,  0.0000, -0.0010, -0.0026, -0.0034,
#         -0.0073, -0.0073]), wdl tensor([0.0840, 0.9160, 0.0000])
# after:               top_moves tensor([0.0062]), wdl tensor([0.1290, 0.8710, 0.0000])
# before move: g8h7, top_moves tensor([-0.0037, -0.0048, -0.0074, -0.0086, -0.0101, -0.0083, -0.0099, -0.0105,
#         -0.0111, -0.0145]), wdl tensor([0.0010, 0.9620, 0.0370])
# after:               top_moves tensor([-0.0118]), wdl tensor([0.0000, 0.2500, 0.7500])
# before move: f1g1, top_moves tensor([ 0.0116,  0.0061,  0.0021,  0.0016,  0.0015,  0.0003, -0.0037, -0.0055,
#         -0.0066,  0.0008]), wdl tensor([0.7290, 0.2710, 0.0000])
# after:               top_moves tensor([0.0062]), wdl tensor([0.1290, 0.8710, 0.0000])
# before move: f8g8, top_moves tensor([-0.0068, -0.0089, -0.0101, -0.0147, -0.0167, -0.0156, -0.0161, -0.0168,
#         -0.0173, -0.0182]), wdl tensor([0.0000, 0.8300, 0.1700])
# after:               top_moves tensor([-0.0181]), wdl tensor([0.0000, 0.0110, 0.9890])
# before move: g1g2, top_moves tensor([0.0203, 0.0176, 0.0152, 0.0123, 0.0100, 0.0089, 0.0080, 0.0080, 0.0068,
#         0.0063]), wdl tensor([0.9970, 0.0030, 0.0000])
# after:               top_moves tensor([-0.0052]), wdl tensor([0.0000, 0.9210, 0.0790])
# before move: f4f3, top_moves tensor([ 0.0047,  0.0041, -0.0043, -0.0073, -0.0095, -0.0106, -0.0111, -0.0121,
#         -0.0133, -0.0135]), wdl tensor([0.0620, 0.9380, 0.0000])
# after:               top_moves tensor([0.0031]), wdl tensor([0.0270, 0.9720, 0.0010])
# before move: g2g3, top_moves tensor([-0.0013, -0.0124, -0.0246, -0.0275, -0.0338, -0.0407, -0.0426, -0.0390,
#         -0.0393, -0.0409]), wdl tensor([0.0030, 0.9870, 0.0100])
# after:               top_moves tensor([-0.0016]), wdl tensor([0.0020, 0.9860, 0.0120])
# before move: h5h4, top_moves tensor([ 0.0014, -0.0063, -0.0082, -0.0092, -0.0119, -0.0120, -0.0141, -0.0144,
#         -0.0145, -0.0155]), wdl tensor([0.0110, 0.9870, 0.0020])
# after:               top_moves tensor([-0.0152]), wdl tensor([0.0000, 0.0510, 0.9490])
# before move: g3f3, top_moves tensor([ 0.0164,  0.0024, -0.0030, -0.0207, -0.0242, -0.0280, -0.0276, -0.0295,
#         -0.0295, -0.0339]), wdl tensor([0.9730, 0.0270, 0.0000])
# after:               top_moves tensor([0.0138]), wdl tensor([0.8980, 0.1020, 0.0000])
# before move: f6h5, top_moves tensor([-0.0140, -0.0160, -0.0189, -0.0203, -0.0222, -0.0236, -0.0257, -0.0259,
#         -0.0266, -0.0271]), wdl tensor([0.0000, 0.0930, 0.9070])
# after:               top_moves tensor([-0.0267]), wdl tensor([0., 0., 1.])
# before move: f3f7, top_moves tensor([0.0295, 0.0180, 0.0180, 0.0178, 0.0174, 0.0168, 0.0157, 0.0156, 0.0126,
#         0.0100]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0312]), wdl tensor([1., 0., 0.])
# before move: h5f4, top_moves tensor([-0.0306, -0.0334, -0.0338, -0.0369, -0.0401, -0.0406, -0.0420, -0.0427,
#         -0.0430, -0.0468]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.0439]), wdl tensor([0., 0., 1.])
# before move: a1g1, top_moves tensor([0.0486, 0.0285, 0.0284, 0.0224, 0.0224, 0.0145, 0.0124, 0.0170, 0.0101,
#         0.0077]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0209]), wdl tensor([0.9980, 0.0020, 0.0000])
# before move: f4e6, top_moves tensor([-0.0215, -0.0342, -0.0374, -0.0410, -0.0499, -0.0451, -0.0454, -0.0483,
#         -0.0492, -0.0536]), wdl tensor([0.0000, 0.0020, 0.9980])
# after:               top_moves tensor([-0.0231]), wdl tensor([0.0000, 0.0010, 0.9990])
# before move: b5d6, top_moves tensor([0.0238, 0.0170, 0.0168, 0.0159, 0.0124, 0.0111, 0.0103, 0.0038, 0.0013,
#         0.0005]), wdl tensor([0.9990, 0.0010, 0.0000])
# after:               top_moves tensor([-0.0298]), wdl tensor([0., 0., 1.])
# before move: d8d6, top_moves tensor([ 0.0311, -0.0213, -0.0363, -0.0337, -0.0344, -0.0350, -0.0362, -0.0377,
#         -0.0416, -0.0444]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0330]), wdl tensor([1., 0., 0.])
# before move: b3b7, top_moves tensor([-0.0262, -0.0306, -0.0268, -0.0275, -0.0309, -0.0311, -0.0313, -0.0317,
#         -0.0355, -0.0361]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.0349]), wdl tensor([0., 0., 1.])
# before move: e7g6, top_moves tensor([ 0.0350,  0.0140,  0.0103,  0.0066,  0.0035,  0.0007,  0.0000,  0.0000,
#         -0.0008, -0.0031]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0122]), wdl tensor([0.7880, 0.2120, 0.0000])
# before move: f7d7, top_moves tensor([-0.0143, -0.0180, -0.0229, -0.0230, -0.0236, -0.0243, -0.0296, -0.0244,
#         -0.0259, -0.0288]), wdl tensor([0.0000, 0.0800, 0.9200])
# after:               top_moves tensor([-0.0216]), wdl tensor([0.0000, 0.0020, 0.9980])
# before move: d6f8, top_moves tensor([ 0.0252,  0.0251,  0.0246,  0.0000, -0.0062, -0.0155, -0.0227, -0.0256,
#         -0.0270, -0.0366]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0216]), wdl tensor([0.9980, 0.0020, 0.0000])
# before move: g1g2, top_moves tensor([-0.0215, -0.0222, -0.0340, -0.0344, -0.0357, -0.0391, -0.0407, -0.0409,
#         -0.0449, -0.0456]), wdl tensor([0.0000, 0.0020, 0.9980])
# after:               top_moves tensor([-0.0388]), wdl tensor([0., 0., 1.])
# before move: f8f4, top_moves tensor([0.0413, 0.0306, 0.0306, 0.0278, 0.0277, 0.0273, 0.0225, 0.0212, 0.0207,
#         0.0207]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0423]), wdl tensor([1., 0., 0.])
# before move: h2g1, top_moves tensor([-0.0433, -0.0460, -0.0851, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#         -1.0000, -1.0000]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.0414]), wdl tensor([0., 0., 1.])
# before move: e6d4, top_moves tensor([0.0441, 0.0350, 0.0327, 0.0342, 0.0338, 0.0331, 0.0301, 0.0300, 0.0272,
#         0.0265]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0300]), wdl tensor([1., 0., 0.])
# before move: d7g7, top_moves tensor([-0.0309, -0.0331, -0.0380, -0.0323, -0.0330, -0.0345, -0.0346, -0.0353,
#         -0.0405, -0.0415]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.0700]), wdl tensor([0., 0., 1.])
# before move: g8g7, top_moves tensor([ 0.0685, -0.9999, -0.9999, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#         -1.0000, -1.0000]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.0733]), wdl tensor([1., 0., 0.])
# before move: b7a8, top_moves tensor([-0.0761, -0.0761, -0.0765, -0.0766, -0.0790, -0.0810, -0.0810, -0.0892,
#         -0.0962, -0.0895]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.9993]), wdl tensor([0., 0., 1.])
# before move: d4f3, top_moves tensor([0.9993, 0.0765, 0.0580, 0.0486, 0.0280, 0.0258, 0.0195, 0.0149, 0.0111,
#         0.0086]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.9994]), wdl tensor([1., 0., 0.])
# before move: g1f1, top_moves tensor([-0.9994, -0.9995, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000, -1.0000,
#         -1.0000, -1.0000]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.9995]), wdl tensor([0., 0., 1.])
# before move: f4d2, top_moves tensor([0.9995, 0.0466, 0.0380, 0.0312, 0.0088, 0.0077, 0.0039, 0.0037, 0.0037,
#         0.0037]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([0.9996]), wdl tensor([1., 0., 0.])
# before move: d3e2, top_moves tensor([-0.9996, -0.9997, -0.9997, -0.9998, -0.9998, -0.9998, -0.9998, -0.9998,
#         -0.9999, -0.9999]), wdl tensor([0., 0., 1.])
# after:               top_moves tensor([-0.9999]), wdl tensor([0., 0., 1.])
# before move: d2e1, top_moves tensor([ 9.9990e-01,  6.4706e-02,  3.5804e-02,  3.1503e-02,  1.9002e-02,
#          1.0001e-02,  6.2006e-03,  0.0000e+00, -4.0004e-04, -9.0009e-03]), wdl tensor([1., 0., 0.])
# after:               top_moves tensor([1.]), wdl tensor([1., 0., 0.])
